# %% [markdown]
# # SAM3 GPU Server Inference
#
# This notebook runs Segment Anything 3 on a CUDA-enabled GPU server.

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# ### Configure HuggingFace Token
#
# To pull Segment Anything 3 weights, you need a HuggingFace Access Token with approved access to the SAM 3 checkpoints.
#
# - Request access to the SAM 3 checkpoints on the official Hugging Face [repo](https://huggingface.co/facebook/sam2-hiera-large)
# - Create a `.env` file in the project root with your token:
#   ```
#   HF_TOKEN=hf_your_token_here
#   ```

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

# Load environment variables from .env file
project_root = Path.cwd().parent.parent
env_path = project_root / ".env"
load_dotenv(env_path)

hf_token = os.getenv("HF_TOKEN")
if not hf_token:
    raise ValueError("HF_TOKEN not found. Please create a .env file with your HuggingFace token.")

os.environ["HF_TOKEN"] = hf_token
print("✓ HuggingFace token loaded successfully")
# Out:
# ✓ HuggingFace token loaded successfully

# %% [markdown]
# ### Check GPU Availability
#
# Verify that CUDA GPU is available and properly configured.

# %%
# !nvidia-smi
# Out:
# Sat Feb 28 13:30:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 590.48.01              Driver Version: 590.48.01      CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   46C    P8             16W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
    print(f"GPU compute capability: {torch.cuda.get_device_properties(0).major}.{torch.cuda.get_device_properties(0).minor}")
else:
    raise RuntimeError("CUDA GPU not available. This notebook requires a CUDA-enabled GPU.")
# Out:
# PyTorch version: 2.10.0+cu128
# Torchvision version: 0.25.0+cu128
# CUDA is available: True
# CUDA version: 12.8
# GPU device: NVIDIA L4
# GPU compute capability: 8.9

# %% [markdown]
# ### Install SAM3 and Dependencies
#
# Clone the official SAM3 repository and install it with required dependencies.

# %%
# Check if sam3 is already cloned
sam3_dir = Path.cwd() / "sam3"

if not sam3_dir.exists():
    print("Cloning SAM3 repository...")
    # !git clone https://github.com/facebookresearch/sam3.git
    print("✓ SAM3 repository cloned")
else:
    print("✓ SAM3 repository already exists")

# Install SAM3 and dependencies
# %cd sam3
# %pip install -e ".[notebooks]"
# %cd ..
# Out:
# ✓ SAM3 repository already exists
# /home/berkaybugragok/cv-urban-accessibility-senior-project/sam3-trials/local-gpu-setup/sam3
# Obtaining file:///home/berkaybugragok/cv-urban-accessibility-senior-project/sam3-trials/local-gpu-setup/sam3
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: timm>=1.0.17 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (1.0.25)
# Requirement already satisfied: numpy<2,>=1.26 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (1.26.4)
# Requirement already satisfied: tqdm in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (4.67.3)
# Requirement already satisfied: ftfy==6.1.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (6.1.1)
# Requirement already satisfied: regex in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (2026.2.28)
# Requirement already satisfied: iopath>=0.1.10 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (0.1.10)
# Requirement already satisfied: typing_extensions in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (4.15.0)
# Requirement already satisfied: huggingface_hub in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (1.5.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ftfy==6.1.1->sam3==0.1.0) (0.6.0)
# Requirement already satisfied: matplotlib in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (3.10.8)
# Requirement already satisfied: jupyter in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (1.1.1)
# Requirement already satisfied: notebook in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (7.5.4)
# Requirement already satisfied: ipywidgets in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (8.1.8)
# Requirement already satisfied: ipycanvas in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (0.14.3)
# Requirement already satisfied: ipympl in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (0.10.0)
# Requirement already satisfied: pycocotools in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (2.0.11)
# Requirement already satisfied: decord in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (0.6.0)
# Requirement already satisfied: opencv-python in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (4.11.0.86)
# Requirement already satisfied: einops in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (0.8.2)
# Requirement already satisfied: scikit-image in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (0.26.0)
# Requirement already satisfied: scikit-learn in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sam3==0.1.0) (1.8.0)
# Requirement already satisfied: portalocker in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from iopath>=0.1.10->sam3==0.1.0) (3.2.0)
# Requirement already satisfied: torch in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from timm>=1.0.17->sam3==0.1.0) (2.10.0)
# Requirement already satisfied: torchvision in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from timm>=1.0.17->sam3==0.1.0) (0.25.0)
# Requirement already satisfied: pyyaml in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from timm>=1.0.17->sam3==0.1.0) (6.0.3)
# Requirement already satisfied: safetensors in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from timm>=1.0.17->sam3==0.1.0) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from huggingface_hub->sam3==0.1.0) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from huggingface_hub->sam3==0.1.0) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from huggingface_hub->sam3==0.1.0) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from huggingface_hub->sam3==0.1.0) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from huggingface_hub->sam3==0.1.0) (26.0)
# Requirement already satisfied: typer in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from huggingface_hub->sam3==0.1.0) (0.24.1)
# Requirement already satisfied: pillow>=6.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipycanvas->sam3==0.1.0) (12.1.1)
# Requirement already satisfied: comm>=0.1.3 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipywidgets->sam3==0.1.0) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipywidgets->sam3==0.1.0) (9.10.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipywidgets->sam3==0.1.0) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipywidgets->sam3==0.1.0) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipywidgets->sam3==0.1.0) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from matplotlib->sam3==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from matplotlib->sam3==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from matplotlib->sam3==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from matplotlib->sam3==0.1.0) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from matplotlib->sam3==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from matplotlib->sam3==0.1.0) (2.9.0.post0)
# Requirement already satisfied: jupyter-console in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter->sam3==0.1.0) (6.6.3)
# Requirement already satisfied: nbconvert in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter->sam3==0.1.0) (7.17.0)
# Requirement already satisfied: ipykernel in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter->sam3==0.1.0) (7.2.0)
# Requirement already satisfied: jupyterlab in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter->sam3==0.1.0) (4.5.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from notebook->sam3==0.1.0) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from notebook->sam3==0.1.0) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from notebook->sam3==0.1.0) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from notebook->sam3==0.1.0) (6.5.4)
# Requirement already satisfied: scipy>=1.11.4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from scikit-image->sam3==0.1.0) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from scikit-image->sam3==0.1.0) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from scikit-image->sam3==0.1.0) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from scikit-image->sam3==0.1.0) (2026.2.24)
# Requirement already satisfied: lazy-loader>=0.4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from scikit-image->sam3==0.1.0) (0.4)
# Requirement already satisfied: joblib>=1.3.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from scikit-learn->sam3==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from scikit-learn->sam3==0.1.0) (3.6.0)
# Requirement already satisfied: anyio in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (4.12.1)
# Requirement already satisfied: certifi in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (1.0.9)
# Requirement already satisfied: idna in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (0.16.0)
# Requirement already satisfied: decorator>=4.3.2 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->sam3==0.1.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->sam3==0.1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->sam3==0.1.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->sam3==0.1.0) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->sam3==0.1.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->sam3==0.1.0) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->sam3==0.1.0) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->sam3==0.1.0) (0.6.3)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->sam3==0.1.0) (2.2.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->sam3==0.1.0) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->sam3==0.1.0) (79.0.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->sam3==0.1.0) (1.8.20)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->sam3==0.1.0) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->sam3==0.1.0) (7.2.2)
# Requirement already satisfied: babel>=2.10 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->sam3==0.1.0) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->sam3==0.1.0) (6.3.0)
# Requirement already satisfied: defusedxml in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->sam3==0.1.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->sam3==0.1.0) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->sam3==0.1.0) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->sam3==0.1.0) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->sam3==0.1.0) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->sam3==0.1.0) (1.5.1)
# Requirement already satisfied: six>=1.5 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->sam3==0.1.0) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (1.14.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from cuda-bindings==12.9.4->torch->timm>=1.0.17->sam3==0.1.0) (1.4.0)
# Requirement already satisfied: click>=8.2.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from typer->huggingface_hub->sam3==0.1.0) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from typer->huggingface_hub->sam3==0.1.0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from typer->huggingface_hub->sam3==0.1.0) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from typer->huggingface_hub->sam3==0.1.0) (0.0.4)
# Requirement already satisfied: argon2-cffi-bindings in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (25.1.0)
# Requirement already satisfied: webencodings in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->sam3==0.1.0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->sam3==0.1.0) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets->sam3==0.1.0) (0.8.6)
# Requirement already satisfied: attrs>=22.2.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (4.9.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->sam3==0.1.0) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook->sam3==0.1.0) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from rich>=12.3.0->typer->huggingface_hub->sam3==0.1.0) (4.0.0)
# Requirement already satisfied: executing>=1.2.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->sam3==0.1.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->sam3==0.1.0) (3.0.1)
# Requirement already satisfied: pure-eval in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->sam3==0.1.0) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch->timm>=1.0.17->sam3==0.1.0) (1.3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->sam3==0.1.0) (2.8.3)
# Requirement already satisfied: fqdn in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (1.5.1)
# Requirement already satisfied: isoduration in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (1.1.0)
# Requirement already satisfied: uri-template in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (25.10.0)
# Requirement already satisfied: mdurl~=0.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->sam3==0.1.0) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (2.0.0)
# Requirement already satisfied: pycparser in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (3.0)
# Requirement already satisfied: lark>=1.2.2 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (1.4.0)
# Requirement already satisfied: tzdata in /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->sam3==0.1.0) (2025.3)
# Checking if build backend supports build_editable ... done
# Building wheels for collected packages: sam3
#   Building editable for sam3 (pyproject.toml) ... done
#   Created wheel for sam3: filename=sam3-0.1.0-0.editable-py3-none-any.whl size=15438 sha256=b72f7a2147f3c58f32cd92b3ae175c76f9ca438446236bd2d2ed2676f2f4742f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9w0gkefj/wheels/c5/6c/de/f29b966ce5f9fb5ceb87a954a82fa6b7a341ae0e68c01cf704
# Successfully built sam3
# Installing collected packages: sam3
#   Attempting uninstall: sam3
#     Found existing installation: sam3 0.1.0
#     Uninstalling sam3-0.1.0:
#       Successfully uninstalled sam3-0.1.0
# Successfully installed sam3-0.1.0
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# /home/berkaybugragok/cv-urban-accessibility-senior-project/sam3-trials/local-gpu-setup

# %%
# Install additional dependencies for visualization and interaction
# %pip install -q supervision jupyter_bbox_widget python-dotenv
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Download Example Data
#
# Download sample images for testing. You can replace these with your own images.

# %%
# Create data directory
data_dir = Path.cwd() / "data"
data_dir.mkdir(exist_ok=True)

# Download example images
images = [
    "solvay_conference_1927.jpg",
    "birds.jpg",
    "pills.jpg",
    "eggs.jpg",
    "traffic_jam.jpg",
    "airport.jpg",
    "basketball_game.jpg",
    "dog-2.jpeg"
]

for img in images:
    img_path = data_dir / img
    if not img_path.exists():
        # !wget -q https://media.roboflow.com/notebooks/examples/{img} -P {data_dir}
        print(f"✓ Downloaded {img}")
    else:
        print(f"✓ {img} already exists")
# Out:
# ✓ Downloaded solvay_conference_1927.jpg
# ✓ Downloaded birds.jpg
# ✓ Downloaded pills.jpg
# ✓ Downloaded eggs.jpg
# ✓ Downloaded traffic_jam.jpg
# ✓ Downloaded airport.jpg
# ✓ Downloaded basketball_game.jpg
# ✓ Downloaded dog-2.jpeg

# %% [markdown]
# ---
# **⚠️ Important: Restart the kernel before running cells below if you just installed SAM3.**
#
# ---

# %% [markdown]
# ## Load SAM3 Image Predictor
#
# On Ampere GPUs (compute capability ≥ 8), we enable TensorFloat-32 (TF32) for matrix multiplications and convolutions. This allows PyTorch to use tensor cores to accelerate FP32 computations while maintaining similar numerical accuracy.

# %%
import torch
from pathlib import Path

# Enable autocast for better performance
torch.autocast(device_type="cuda", dtype=torch.bfloat16).__enter__()

# Enable TF32 on Ampere GPUs for better performance
if torch.cuda.get_device_properties(0).major >= 8:
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True
    print("✓ TF32 enabled for Ampere GPU")
else:
    print("ℹ GPU compute capability < 8, TF32 not available")
# Out:
# ✓ TF32 enabled for Ampere GPU

# %%
# Diagnostic: Check Python version and sam3 installation
import sys
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")

# Check if sam3 is in site-packages
import site
print(f"\nSite packages: {site.getsitepackages()}")

# Try to locate sam3
try:
    import sam3
    print(f"\n✓ sam3 module found at: {sam3.__file__}")
except ImportError as e:
    print(f"\n✗ sam3 module not found: {e}")
    print("\nPlease restart the kernel: Kernel -> Restart Kernel")
# Out:
# Python version: 3.11.14 (main, Oct 10 2025, 08:54:04) [GCC 13.3.0]
# Python executable: /home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/bin/python
#
# Site packages: ['/home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/site-packages', '/home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/local/lib/python3.11/dist-packages', '/home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3/dist-packages', '/home/berkaybugragok/cv-urban-accessibility-senior-project/.venv/lib/python3.11/dist-packages']
#
# ✓ sam3 module found at: None

# %%
# Import sam3 - it should be available from the editable install
# If this fails, restart the kernel (Kernel -> Restart Kernel)
from sam3.model_builder import build_sam3_image_model
from sam3.model.sam3_image_processor import Sam3Processor

# Build the model - bpe_path should point to the assets in the installed package
bpe_path = Path.cwd() / "sam3" / "sam3" / "assets" / "bpe_simple_vocab_16e6.txt.gz"
model = build_sam3_image_model(bpe_path=str(bpe_path))
processor = Sam3Processor(model, confidence_threshold=0.3)

print("✓ SAM3 model loaded successfully")
# Out:
# config.json:   0%|          | 0.00/25.8k [00:00<?, ?B/s]
# sam3.pt:   0%|          | 0.00/3.45G [00:00<?, ?B/s]
# ✓ SAM3 model loaded successfully

# %% [markdown]
# ## Utility Functions for Visualization

# %%
import supervision as sv
import numpy as np

def from_sam(sam_result: dict) -> sv.Detections:
    """Convert SAM3 results to Supervision Detections format."""
    xyxy = sam_result["boxes"].to(torch.float32).cpu().numpy()
    confidence = sam_result["scores"].to(torch.float32).cpu().numpy()

    mask = sam_result["masks"].to(torch.bool)
    mask = mask.reshape(mask.shape[0], mask.shape[2], mask.shape[3]).cpu().numpy()

    return sv.Detections(
        xyxy=xyxy,
        confidence=confidence,
        mask=mask
    )

# %%
import supervision as sv
from PIL import Image
from typing import Optional

# Define color palette for visualizations
COLOR = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])


def annotate(image: Image.Image, detections: sv.Detections, label: Optional[str] = None) -> Image.Image:
    """Annotate image with detection results."""
    text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)

    mask_annotator = sv.MaskAnnotator(
        color=COLOR,
        color_lookup=sv.ColorLookup.INDEX,
        opacity=0.6
    )
    box_annotator = sv.BoxAnnotator(
        color=COLOR,
        color_lookup=sv.ColorLookup.INDEX,
        thickness=1
    )
    label_annotator = sv.LabelAnnotator(
        color=COLOR,
        color_lookup=sv.ColorLookup.INDEX,
        text_scale=0.4,
        text_padding=5,
        text_color=sv.Color.BLACK,
        text_thickness=1
    )

    annotated_image = image.copy()
    annotated_image = mask_annotator.annotate(annotated_image, detections)
    annotated_image = box_annotator.annotate(annotated_image, detections)

    if label:
        labels = [
            f"{label} {confidence:.2f}"
            for confidence in detections.confidence
        ]
        annotated_image = label_annotator.annotate(annotated_image, detections, labels)

    return annotated_image

# %% [markdown]
# ## SAM3 Text Prompt
#
# Segment objects using text descriptions.

# %%
from PIL import Image
from IPython.display import display

data_dir = Path.cwd() / "data"
PROMPT = "taxi"
IMAGE_PATH = data_dir / "traffic_jam.jpg"

image = Image.open(IMAGE_PATH).convert("RGB")
inference_state = processor.set_image(image)
inference_state = processor.set_text_prompt(state=inference_state, prompt=PROMPT)

detections = from_sam(sam_result=inference_state)
detections = detections[detections.confidence > 0.5]

print(f"There are {len(detections)} {PROMPT} objects detected in the image.\n")
annotated = annotate(image, detections, label=PROMPT)
display(annotated)
# Out:
# There are 16 taxi objects detected in the image.
# <PIL.Image.Image image mode=RGB size=1023x682>

# %% [markdown]
# ## SAM3 Box Prompt
#
# Segment objects by drawing bounding boxes.

# %% [markdown]
# ## Utility Functions for Visualization

# %%
import base64
from io import BytesIO
from PIL import Image

OBJECTS = ['positive', 'negative']

def encode_image_pillow(image: Image.Image) -> str:
    """Encode PIL Image to base64 string for widget display."""
    buffer = BytesIO()
    image.save(buffer, format="JPEG")
    image_bytes = buffer.getvalue()
    encoded = base64.b64encode(image_bytes).decode("utf-8")
    return "data:image/jpeg;base64," + encoded

# %% [markdown]
# When prompting SAM 3 with bounding boxes, the model expects boxes in the `xcycwh` format (`x_center`, `y_center`, `width`, `height`), and the coordinates must be normalized. The code below handles the conversion to this format.

# %%
import numpy as np

def get_normalized_boxes(bboxes, label, resolution_wh):
    """Convert bounding boxes to normalized xcycwh format."""
    width, height = resolution_wh
    boxes = [
        [b["x"] + b["width"] / 2, b["y"] + b["height"] / 2, b["width"], b["height"]]
        for b in bboxes
        if b["label"] == label
    ]
    if not boxes:
        return np.empty((0, 4), dtype=np.float32)
    scale = np.array([width, height, width, height], dtype=np.float32).reshape(1,-1)
    return np.array(boxes, dtype=np.float32) / scale

# %%
from PIL import Image
from jupyter_bbox_widget import BBoxWidget

image_path = data_dir / "birds.jpg"
image = Image.open(image_path).convert("RGB")

widget = BBoxWidget(classes=OBJECTS)
widget.image = encode_image_pillow(image)
widget

# %%
# After drawing boxes in the widget above, run this to see results
# Uncomment and run when ready:

# positive_boxes = get_normalized_boxes(widget.bboxes, "positive", image.size)
# negative_boxes = get_normalized_boxes(widget.bboxes, "negative", image.size)

# inference_state = processor.set_image(image)
# inference_state = processor.set_box_prompt(
#     state=inference_state,
#     positive_boxes=positive_boxes,
#     negative_boxes=negative_boxes
# )

# detections = from_sam(sam_result=inference_state)
# detections = detections[detections.confidence > 0.3]

# print(f"Detected {len(detections)} objects")
# annotated = annotate(image, detections)
# display(annotated)

# %% [markdown]
# ## Load SAM3 Interactive Image Predictor
#
# Segment Anything Model 3 (SAM 3) predicts object masks given prompts that indicate the desired object. The model first converts the image into an image embedding that allows high quality masks to be efficiently produced from a prompt.

# %% [markdown]
# `SAM3InteractiveImagePredictor.predict` takes the following arguments:
#
# - `point_coords` - `[np.ndarray or None]` - a `Nx2` array of point prompts to the model. Each point is in `(X,Y)` in pixels.
# - `point_labels` - `[np.ndarray or None]` - a length `N` array of labels for the point prompts. `1` indicates a foreground point and `0` indicates a background point.
# - `box` - `[np.ndarray or None]` - a length `4` array given a box prompt to the model, in `[x_min, y_min, x_max, y_max]` format.
# - `mask_input` - `[np.ndarray]` - a low resolution mask input to the model, typically coming from a previous prediction iteration. Has form `1xHxW`, where for SAM, `H=W=256`.
# - `multimask_output` - `[bool]` - if true, the model will return three masks. For ambiguous input prompts (such as a single click), this will often produce better masks than a single prediction. If only a single mask is needed, the model's predicted quality score can be used to select the best mask. For non-ambiguous prompts, such as multiple input prompts, `multimask_output=False` can give better results.
# - `return_logits` - `[bool]` - if true, returns un-thresholded masks logits instead of a binary mask.
# - `normalize_coords` - `[bool]` - if true, the point coordinates will be normalized to the range `[0,1]` and point_coords is expected to be wrt. image dimensions.

# %%
# Load model with interactive mode enabled
bpe_path = Path.cwd() / "sam3" / "sam3" / "assets" / "bpe_simple_vocab_16e6.txt.gz"
model = build_sam3_image_model(bpe_path=str(bpe_path), enable_inst_interactivity=True)
processor = Sam3Processor(model, confidence_threshold=0.3)

print("✓ SAM3 interactive model loaded successfully")

# %%
def from_sam_interactive(sam_result: tuple[np.ndarray, np.ndarray]) -> sv.Detections:
    """Convert interactive SAM3 results to Supervision Detections format."""
    masks, scores = sam_result

    if masks.shape[0] != 1:
        masks = np.squeeze(masks)

    return sv.Detections(
        xyxy=sv.mask_to_xyxy(masks=masks),
        mask=masks.astype(bool),
        confidence=np.squeeze(scores)
    )

# %%
import numpy as np

def get_xy_points(boxes, label):
    """Extract center points from bounding boxes."""
    points = [
        [b["x"] + b["width"] / 2, b["y"] + b["height"] / 2]
        for b in boxes
        if b["label"] == label
    ]
    if not points:
        return np.empty((0, 2), dtype=np.float32)
    return np.array(points, dtype=np.float32)


def get_xyxy_boxes(boxes, label):
    """Convert boxes to xyxy format."""
    boxes = [
        [b["x"], b["y"], b["x"] + b["width"], b["y"] + b["height"]]
        for b in boxes
        if b["label"] == label
    ]
    if not boxes:
        return np.empty((0, 4), dtype=np.float32)
    return np.array(boxes, dtype=np.float32)

# %% [markdown]
# ## Interactive SAM3 Box Prompt

# %%
from PIL import Image
from jupyter_bbox_widget import BBoxWidget

image_path = data_dir / "dog-2.jpeg"
image = Image.open(image_path).convert("RGB")

widget = BBoxWidget(classes=OBJECTS)
widget.image = encode_image_pillow(image)
widget

# %%
# After drawing boxes in the widget above, run this to see results
# Uncomment and run when ready:

# positive_boxes = get_xyxy_boxes(widget.bboxes, "positive")
# negative_boxes = get_xyxy_boxes(widget.bboxes, "negative")

# inference_state = processor.set_image(image)

# # Process positive boxes
# for box in positive_boxes:
#     masks, scores = processor.predict(
#         inference_state=inference_state,
#         box=box,
#         multimask_output=False
#     )
#     detections = from_sam_interactive((masks, scores))
#     annotated = annotate(image, detections)
#     display(annotated)

# %% [markdown]
# ## Interactive SAM3 Point Prompt

# %%
from PIL import Image
from jupyter_bbox_widget import BBoxWidget

image_path = data_dir / "dog-2.jpeg"
image = Image.open(image_path).convert("RGB")

widget = BBoxWidget(classes=OBJECTS)
widget.image = encode_image_pillow(image)
widget

# %%
# After clicking points in the widget above, run this to see results
# Uncomment and run when ready:

# positive_points = get_xy_points(widget.bboxes, "positive")
# negative_points = get_xy_points(widget.bboxes, "negative")

# if len(positive_points) > 0 or len(negative_points) > 0:
#     # Combine points and labels
#     all_points = np.vstack([positive_points, negative_points]) if len(negative_points) > 0 else positive_points
#     point_labels = np.array(
#         [1] * len(positive_points) + [0] * len(negative_points),
#         dtype=np.int32
#     )
    
#     inference_state = processor.set_image(image)
#     masks, scores = processor.predict(
#         inference_state=inference_state,
#         point_coords=all_points,
#         point_labels=point_labels,
#         multimask_output=True
#     )
    
#     detections = from_sam_interactive((masks, scores))
#     annotated = annotate(image, detections)
#     display(annotated)
# else:
#     print("Please add some points using the widget above")

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook demonstrates how to run SAM3 on a CUDA-enabled GPU server with:
#
# - **Text prompts**: Segment objects by describing them in natural language
# - **Box prompts**: Segment objects by drawing bounding boxes
# - **Point prompts**: Segment objects by clicking points (foreground/background)
# - **Interactive mode**: Real-time segmentation with user feedback
#
# The notebook is optimized for CUDA GPUs and includes TF32 acceleration for Ampere and newer architectures.
#
# ---
